# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kamini25singh/assignment/blob/master/Untitled0.ipynb)

# %%
import numpy as np

# %%
#Question 1
a=np.random.rand(10,1)
print(a)
a.mean()
# Out:
# [[0.43788399]
#  [0.65381279]
#  [0.64443995]
#  [0.33268401]
#  [0.0103546 ]
#  [0.40396695]
#  [0.38179201]
#  [0.67907804]
#  [0.54494961]
#  [0.46881495]]
# 0.4557776883851923

# %%
#Queation 2
b=np.random.rand(20,1)
print(b)
b.var()
# Out:
# [[0.65877768]
#  [0.45969848]
#  [0.70159728]
#  [0.15567084]
#  [0.77183053]
#  [0.69722526]
#  [0.4386331 ]
#  [0.37585817]
#  [0.8707765 ]
#  [0.22312167]
#  [0.59132755]
#  [0.57939309]
#  [0.91547026]
#  [0.35701102]
#  [0.26162987]
#  [0.82363919]
#  [0.64842954]
#  [0.40166601]
#  [0.26993427]
#  [0.62573041]]
# 0.0483809095644097

# %%
#Question 3
A=np.random.rand(10,20)
print(A)
B=np.random.rand(20,25)
print(B)
C=np.dot(A,B)
print(C)
# Out:
# [[7.57024010e-01 6.34283671e-01 5.50776191e-01 3.32891243e-01
#   6.63112379e-02 7.21291806e-01 2.18718755e-02 3.79625376e-01
#   6.49500332e-01 9.39546018e-01 7.08916412e-01 1.29329366e-01
#   9.66194254e-01 6.93004476e-01 9.15655339e-01 3.25000067e-01
#   7.18199058e-01 9.05219982e-01 3.24103560e-01 8.79114380e-01]
#  [7.94242938e-01 8.61310630e-01 7.77505563e-01 1.70373454e-01
#   8.47682340e-02 4.71458852e-01 5.35521861e-01 3.27734909e-01
#   5.87482152e-01 1.69702191e-01 4.17311967e-01 1.50994020e-01
#   8.91971666e-01 1.56831441e-01 8.84185194e-01 8.38541366e-01
#   4.98512828e-01 9.41776100e-01 9.92787755e-01 8.68728126e-03]
#  [9.22057333e-01 5.46789540e-01 7.94138316e-01 6.68625139e-02
#   8.54959783e-01 5.67549386e-01 8.16062104e-01 6.47792463e-01
#   4.49916059e-02 4.88704092e-01 6.68564680e-01 9.92047822e-02
#   3.25318844e-02 5.59122398e-01 7.72525486e-01 9.59119019e-01
#   6.54729032e-01 5.75209582e-01 5.49299917e-01 1.96792170e-02]
# ...

# %%
#Question 4
b=np_arange(10).reshape(10,1)
print(b)
def f(x):
   return 1/(1+math.exp(-x))
np.apply_along_axis(f,1,b)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-e4611522f6d2> in <module>()
# ----> 1 b=np_arange(10).reshape(10,1)
#       2 print(b)
#       3 def f(x):
#       4    return 1/(1+math.exp(-x))
#       5 np.apply_along_axis(f,1,b)
#
# NameError: name 'np_arange' is not defined
